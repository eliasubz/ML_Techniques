# %% [markdown]
# # Hyperparameter Search Notebook

# %% [markdown]
# ## Set up and configuration

# %%
import time
import json
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

from Parser import Parser
from IBL import IBL
from preprocessing_types import (
    NormalizationStrategy, EncodingStrategy,
    MissingValuesNumericStrategy, MissingValuesCategoricalStrategy
)

BASE = "../datasetsCBR/datasetsCBR"
NUM_SPLITS = 10

K_LIST = [3, 5, 7]
METRICS_EUC_COS = ["euclidean", "cosine"] # separated euclidean/cosine vs heom for compatibility
METRIC_HEOM = ["heom"]
VOTES = ["modified_plurality"]
RETENTIONS = ["never_retain"]

# K_LIST = [5]
# METRICS_EUC_COS = ["euclidean"] # separated euclidean/cosine vs heom for compatibility
# METRIC_HEOM = ["heom"]
# VOTES = ["modified_plurality"]
# RETENTIONS = ["different_class_retention"]

# %% [markdown]
# ## Suite Runner

# %%
def split_xy(df: pd.DataFrame):
    """Split last column as y; return X (DF), y (Series), name of target col."""
    target_col = df.columns[-1]
    X = df.drop(columns=[target_col])
    y = df[target_col]
    return X, y, target_col

def cm_to_json(cm: np.ndarray, labels: list | None = None) -> str:
    d = {"labels": labels if labels is not None else list(range(cm.shape[0])),
         "matrix": cm.astype(int).tolist()}
    return json.dumps(d)

def run_suite(
    dataset_name: str,
    metrics: list[str],
    encoding_for_metrics: dict[str, EncodingStrategy | None],
    csv_path: str,
    run_retentions: list[str] = RETENTIONS,
):
    rows = []

    for metric in metrics:
        enc_strategy = encoding_for_metrics[metric]
        # Build a fresh Parser for this metric so preprocessing matches (OHE vs LE)
        parser = Parser(
            base_path=BASE,
            dataset_name=dataset_name,
            normalization_strategy=NormalizationStrategy.MINMAX_SCALING,   # numeric -> [0,1]
            encoding_strategy=enc_strategy,                         # OHE for eucl/cos, LE or None for HEOM
            missing_values_numeric_strategy=MissingValuesNumericStrategy.MEDIAN,
            missing_values_categorical_strategy=MissingValuesCategoricalStrategy.MODE,
            num_splits=NUM_SPLITS,
        )

        types = parser.get_types()

        for fold in range(NUM_SPLITS):
            train_matrix, test_matrix = parser.get_split(fold)
            X_train, y_train, target = split_xy(train_matrix)
            X_test, y_test, _ = split_xy(test_matrix)

            for k in K_LIST:
                for vote in VOTES:
                    for retention in run_retentions:

                        ibl = IBL()

                        # Time fit + predict
                        t0 = time.perf_counter()
                        ibl.fit(train_matrix)
                        t1 = time.perf_counter()
                        preds = ibl.run(test_matrix,  k=k, metric=metric, vote=vote,  retention_policy=retention, types=types)
                       
                        t2 = time.perf_counter()

                        # Metrics
                        y_true = np.asarray(y_test)
                        y_pred = np.asarray(preds)
                       
                        acc = accuracy_score(y_true, y_pred)
                        prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
                            y_true, y_pred, average="macro", zero_division=0
                        )
                        # If you want per-class too:
                        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
                            y_true, y_pred, average="weighted", zero_division=0
                        )
                        labels = np.unique(np.concatenate([y_true, y_pred]))
                        cm = confusion_matrix(y_true, y_pred, labels=labels)

                        rows.append({
                            "dataset": dataset_name,
                            "fold": fold,
                            "metric": metric,
                            "k": k,
                            "vote": vote,
                            "retention": retention,
                            "n_train": len(X_train),
                            "n_test": len(X_test),
                            "fit_time_s": t1 - t0,
                            "predict_time_s": t2 - t1,
                            "total_time_s": t2 - t0,
                            "accuracy": acc,
                            "precision_macro": prec_macro,
                            "recall_macro": rec_macro,
                            "f1_macro": f1_macro,
                            "precision_weighted": prec_w,
                            "recall_weighted": rec_w,
                            "f1_weighted": f1_w,
                            "confusion_matrix_json": cm_to_json(cm, labels=labels.tolist()),
                        })

    df = pd.DataFrame(rows)
    df.to_csv(csv_path, index=False)
    return df

# %% [markdown]
# ## Main (tests)

# %%
df_11 = run_suite(
    dataset_name="adult",
    metrics=METRICS_EUC_COS,
    encoding_for_metrics={
        "euclidean": EncodingStrategy.ONE_HOT_ENCODE,
        "cosine":    EncodingStrategy.ONE_HOT_ENCODE,
    },
    csv_path="results_adult_eucl_cos.csv",
)

df_12 = run_suite(
    dataset_name="adult",
    metrics=METRIC_HEOM,
    encoding_for_metrics={
        "heom": EncodingStrategy.LABEL_ENCODE  # or None if your Parser encodes cats by default for HEOM
    },
    csv_path="results_adult_heom.csv",
)

# df_2 = run_suite(
#     dataset_name="pen-based",
#     metrics=METRICS_EUC_COS,
#     encoding_for_metrics={
#         "euclidean": EncodingStrategy.ONE_HOT_ENCODE,
#         "cosine":    EncodingStrategy.ONE_HOT_ENCODE,
#     },
#     csv_path="results_penbased_eucl_cos.csv",
# )
# Out:
# Total time for all instances: 121.04s
# Total time for all instances: 456.29s
# Total time for all instances: 180.90s
# Total time for all instances: 223.64s
# Total time for all instances: 120.12s
# Total time for all instances: 453.19s
# Total time for all instances: 188.32s
# Total time for all instances: 223.54s
# Total time for all instances: 120.73s
# Total time for all instances: 453.80s
# Total time for all instances: 179.16s
# Total time for all instances: 184.15s
# Total time for all instances: 119.84s
# Total time for all instances: 453.90s
# Total time for all instances: 181.80s
# Total time for all instances: 183.78s
# Total time for all instances: 120.48s
# Total time for all instances: 454.60s
# Total time for all instances: 177.56s
# Total time for all instances: 220.38s
# Total time for all instances: 120.38s
# Total time for all instances: 455.83s
# Total time for all instances: 179.10s
# Total time for all instances: 221.07s
# Total time for all instances: 119.90s
# Total time for all instances: 456.02s
# Total time for all instances: 180.46s
# Total time for all instances: 227.25s
# Total time for all instances: 120.82s
# Total time for all instances: 797.68s
# Total time for all instances: 310.64s
# Total time for all instances: 380.73s
# Total time for all instances: 190.47s
# Total time for all instances: 796.59s
# Total time for all instances: 295.98s
# Total time for all instances: 309.94s
# Total time for all instances: 190.39s
# Total time for all instances: 796.95s
# Total time for all instances: 299.63s
# Total time for all instances: 310.46s
# Total time for all instances: 181.51s
# Total time for all instances: 784.55s
# Total time for all instances: 283.11s
# Total time for all instances: 364.53s
# Total time for all instances: 174.55s
# Total time for all instances: 752.72s
# Total time for all instances: 268.57s
# Total time for all instances: 344.56s
# Total time for all instances: 168.16s
# Total time for all instances: 757.88s
# Total time for all instances: 280.29s
# Total time for all instances: 357.40s
# Total time for all instances: 168.08s
# Total time for all instances: 760.66s
# Total time for all instances: 294.88s
# Total time for all instances: 358.63s
# Total time for all instances: 168.69s
# Total time for all instances: 764.03s
# Total time for all instances: 274.57s
# Total time for all instances: 294.19s
# Total time for all instances: 168.54s
# Total time for all instances: 765.81s
# Total time for all instances: 280.04s
# Total time for all instances: 293.44s
# Total time for all instances: 167.98s
# Total time for all instances: 763.00s
# Total time for all instances: 268.13s
# Total time for all instances: 351.97s
# Total time for all instances: 166.44s
# Total time for all instances: 765.37s
# Total time for all instances: 276.87s
# Total time for all instances: 353.12s
# Total time for all instances: 165.75s
# Total time for all instances: 765.15s
# Total time for all instances: 272.66s
# Total time for all instances: 358.13s
# Total time for all instances: 166.25s
# Total time for all instances: 766.64s
# Total time for all instances: 294.45s
# Total time for all instances: 357.94s
# Total time for all instances: 166.53s
# Total time for all instances: 770.05s
# Total time for all instances: 267.89s
# Total time for all instances: 288.20s
# Total time for all instances: 165.88s
# Total time for all instances: 771.82s
# Total time for all instances: 275.20s
# Total time for all instances: 289.31s
# Total time for all instances: 166.49s
# Total time for all instances: 771.35s
# Total time for all instances: 262.69s
# Total time for all instances: 351.62s
# Total time for all instances: 166.36s
# Total time for all instances: 780.06s
# Total time for all instances: 276.42s
# Total time for all instances: 361.43s
# Total time for all instances: 172.60s
# Total time for all instances: 777.17s
# Total time for all instances: 280.80s
# Total time for all instances: 372.30s
# Total time for all instances: 176.67s
# Total time for all instances: 795.57s
# Total time for all instances: 306.49s
# Total time for all instances: 376.86s
# Total time for all instances: 180.42s
# Total time for all instances: 803.02s
# Total time for all instances: 289.72s
# Total time for all instances: 308.64s
# Total time for all instances: 181.54s
# Total time for all instances: 811.40s
# Total time for all instances: 295.48s
# Total time for all instances: 306.55s
# Total time for all instances: 179.88s
# Total time for all instances: 808.65s
# Total time for all instances: 282.75s
# Total time for all instances: 374.10s
# Total time for all instances: 183.21s
# Total time for all instances: 805.37s
# Total time for all instances: 284.15s
# Total time for all instances: 371.36s
# Total time for all instances: 179.82s
# Total time for all instances: 788.94s
# Total time for all instances: 181.50s
# Total time for all instances: 227.35s
# Total time for all instances: 121.37s
# Total time for all instances: 460.30s
# Total time for all instances: 184.53s
# Total time for all instances: 220.85s
# Total time for all instances: 112.78s
# Total time for all instances: 482.84s
# Total time for all instances: 173.57s
# Total time for all instances: 184.73s
# Total time for all instances: 119.03s
# Total time for all instances: 484.92s
# Total time for all instances: 187.32s
# Total time for all instances: 206.33s
# Total time for all instances: 135.57s
# Total time for all instances: 496.04s
# Total time for all instances: 224.09s
# Total time for all instances: 402.90s
# Total time for all instances: 193.94s
# Total time for all instances: 874.16s
# Total time for all instances: 323.82s
# Total time for all instances: 406.61s
# Total time for all instances: 199.31s
# Total time for all instances: 867.60s
# Total time for all instances: 314.82s
# Total time for all instances: 404.81s
# Total time for all instances: 190.15s
# Total time for all instances: 863.77s
# Total time for all instances: 322.22s
# Total time for all instances: 396.39s
# Total time for all instances: 180.99s
# Total time for all instances: 865.67s
# Total time for all instances: 304.35s
# Total time for all instances: 318.26s
# Total time for all instances: 181.02s
# Total time for all instances: 863.02s
# Total time for all instances: 306.48s
# Total time for all instances: 316.81s
# Total time for all instances: 179.58s
# Total time for all instances: 862.92s
# Total time for all instances: 298.44s
# Total time for all instances: 391.27s
# Total time for all instances: 179.96s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_11 = run_suite(
#       2     dataset_name="adult",
#       3     metrics=METRICS_EUC_COS,
#       4     encoding_for_metrics={
#       5         "euclidean": EncodingStrategy.ONE_HOT_ENCODE,
#       6         "cosine":    EncodingStrategy.ONE_HOT_ENCODE,
#       7     },
#       8     csv_path="results_adult_eucl_cos.csv",
#       9 )
#      11 df_12 = run_suite(
#      12     dataset_name="adult",
#      13     metrics=METRIC_HEOM,
#    (...)     17     csv_path="results_adult_heom.csv",
#      18 )
#      20 # df_2 = run_suite(
#      21 #     dataset_name="pen-based",
#      22 #     metrics=METRICS_EUC_COS,
#    (...)     27 #     csv_path="results_penbased_eucl_cos.csv",
#      28 # )
#
# Cell In[2], line 52, in run_suite(dataset_name, metrics, encoding_for_metrics, csv_path, run_retentions)
#      50 ibl.fit(train_matrix)
#      51 t1 = time.perf_counter()
# ---> 52 preds = ibl.run(test_matrix,  k=k, metric=metric, vote=vote,  retention_policy=retention, types=types)
#      54 t2 = time.perf_counter()
#      56 # Metrics
#
# File c:\Users\Daniel Hess\Documents\Master\IML\ML_Techniques\src\IBL.py:42, in IBL.run(self, test_matrix, k, metric, vote, retention_policy, types)
#      40 dist_start = time.time()
#      41 if self.metric == "euclidean":
# ---> 42     distances = euclidean_distance(X, x_instance)
#      43 elif self.metric == "cosine":
#      44     distances = cosine_distance(X, x_instance)
#
# File c:\Users\Daniel Hess\Documents\Master\IML\ML_Techniques\src\distance_measures.py:7, in euclidean_distance(X, instance)
#       5 def euclidean_distance(X, instance):
#       6     """Compute Euclidean distance of one instance to all in X (assume no missing, treat all columns as numeric)."""
# ----> 7     X_np = X.values.astype(float)
#       8     instance_np = instance.values.astype(float)
#      10     dists = np.sqrt(np.sum((X_np - instance_np) ** 2, axis=1))
#
# KeyboardInterrupt:
