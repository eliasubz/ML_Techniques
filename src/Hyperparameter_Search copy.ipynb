# %% [markdown]
# # Hyperparameter Search Notebook

# %% [markdown]
# Set up parser

# %%
import time
import json
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix

from Parser import Parser
from IBL import IBL
from preprocessing_types import (
    NormalizationStrategy, EncodingStrategy,
    MissingValuesNumericStrategy, MissingValuesCategoricalStrategy
)

BASE = "../datasetsCBR/datasetsCBR"
NUM_SPLITS = 1  # or whatever your dataset folder has

K_LIST = [3, 5, 7]
METRICS_EUC_COS = ["euclidean", "cosine"]
METRIC_HEOM = ["heom"]
VOTES = ["modified_plurality", "borda"]
RETENTIONS = ["NR", "AR", "DC", "DD"]  # implement later; run NR now if needed

# %%
def split_xy(df: pd.DataFrame):
    """Split last column as y; return X (DF), y (Series), name of target col."""
    target_col = df.columns[-1]
    X = df.drop(columns=[target_col])
    y = df[target_col]
    return X, y, target_col

def cm_to_json(cm: np.ndarray, labels: list | None = None) -> str:
    d = {"labels": labels if labels is not None else list(range(cm.shape[0])),
         "matrix": cm.astype(int).tolist()}
    return json.dumps(d)

def run_suite(
    dataset_name: str,
    metrics: list[str],
    encoding_for_metrics: dict[str, EncodingStrategy | None],
    csv_path: str,
    run_retentions: list[str] = RETENTIONS,
):
    rows = []

    for metric in metrics:
        enc_strategy = encoding_for_metrics[metric]
        # Build a fresh Parser for this metric so preprocessing matches (OHE vs LE)
        parser = Parser(
            base_path=BASE,
            dataset_name=dataset_name,
            normalization_strategy=NormalizationStrategy.MINMAX_SCALING,   # numeric -> [0,1]
            encoding_strategy=enc_strategy,                         # OHE for eucl/cos, LE or None for HEOM
            missing_values_numeric_strategy=MissingValuesNumericStrategy.MEDIAN,
            missing_values_categorical_strategy=MissingValuesCategoricalStrategy.MODE,
            num_splits=NUM_SPLITS,
        )

        # If you rely on parser.get_types(), capture it once (HEOM path).
        types = parser.get_types()

        for fold in range(NUM_SPLITS):
            train_df, test_df = parser.get_split(fold)
            Xtr_df, ytr, target = split_xy(train_df)
            Xte_df, yte, _ = split_xy(test_df)

            for k in K_LIST:
                for vote in VOTES:
                    for retention in run_retentions:
                        # If retention not implemented yet, enforce NR now to avoid surprises
                        if retention != "NR":
                            pass  # TODO: wire your retention policy here

                        # Build IBL
                        ibl = IBL()

                        # Time fit + predict
                        t0 = time.perf_counter()
                        ibl.fit(Xtr_df)
                        t1 = time.perf_counter()
                        preds = ibl.run(Xte_df,  k=k, metric=metric, vote=vote, types=types)
                        t2 = time.perf_counter()

                        # Metrics
                        y_true = np.asarray(yte)
                        y_pred = np.asarray(preds)
                        print(y_true)
                        print(y_pred)
                        acc = accuracy_score(y_true, y_pred)
                        prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
                            y_true, y_pred, average="macro", zero_division=0
                        )
                        # If you want per-class too:
                        prec_w, rec_w, f1_w, _ = precision_recall_fscore_support(
                            y_true, y_pred, average="weighted", zero_division=0
                        )
                        labels = np.unique(np.concatenate([y_true, y_pred]))
                        cm = confusion_matrix(y_true, y_pred, labels=labels)

                        rows.append({
                            "dataset": dataset_name,
                            "fold": fold,
                            "metric": metric,
                            "k": k,
                            "vote": vote,
                            "retention": retention,
                            "n_train": len(Xtr_df),
                            "n_test": len(Xte_df),
                            "fit_time_s": t1 - t0,
                            "predict_time_s": t2 - t1,
                            "total_time_s": t2 - t0,
                            "accuracy": acc,
                            "precision_macro": prec_macro,
                            "recall_macro": rec_macro,
                            "f1_macro": f1_macro,
                            "precision_weighted": prec_w,
                            "recall_weighted": rec_w,
                            "f1_weighted": f1_w,
                            "confusion_matrix_json": cm_to_json(cm, labels=labels.tolist()),
                        })

    df = pd.DataFrame(rows)
    df.to_csv(csv_path, index=False)
    return df

# %%
# df_11 = run_suite(
#     dataset_name="adult",
#     metrics=METRICS_EUC_COS,
#     encoding_for_metrics={
#         "euclidean": EncodingStrategy.ONE_HOT_ENCODE,
#         "cosine":    EncodingStrategy.ONE_HOT_ENCODE,
#     },
#     csv_path="results_adult_eucl_cos.csv",
# )

# TEST 1.2: Adult — HEOM (LE)
# df_12 = run_suite(
#     dataset_name="adult",
#     metrics=METRIC_HEOM,
#     encoding_for_metrics={
#         "heom": EncodingStrategy.LABEL_ENCODE  # or None if your Parser encodes cats by default for HEOM
#     },
#     csv_path="results_adult_heom.csv",
# )

# TEST 2: Pen-based — Euclidean & Cosine (OHE is harmless here; no cats)
df_2 = run_suite(
    dataset_name="pen-based",
    metrics=METRICS_EUC_COS,
    encoding_for_metrics={
        "euclidean": EncodingStrategy.ONE_HOT_ENCODE,
        "cosine":    EncodingStrategy.ONE_HOT_ENCODE,
    },
    csv_path="results_penbased_eucl_cos.csv",
)
# Out:
# Instance 0: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 2: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 3: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 4: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 5: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 6: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 7: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 8: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 9: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 10: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 11: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 12: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 13: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 14: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 15: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 16: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 17: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 18: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0020s
# Instance 19: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 20: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 21: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 22: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 23: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0005s, total=0.0020s
# Instance 24: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 25: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 26: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 27: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 28: dist=0.0005s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 29: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 30: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 31: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 32: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 33: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 34: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 35: dist=0.0005s, sort=0.0005s, vote=0.0010s, retention=0.0005s, total=0.0025s
# Instance 36: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 37: dist=0.0010s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0025s
# Instance 38: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 39: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 40: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 41: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 42: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 43: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 44: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0010s
# Instance 45: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 46: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 47: dist=0.0005s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 48: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 49: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 50: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 51: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 52: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 53: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 54: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 55: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 56: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 57: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 58: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0010s
# Instance 59: dist=0.0000s, sort=0.0010s, vote=0.0010s, retention=0.0010s, total=0.0030s
# Instance 60: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0010s, total=0.0025s
# Instance 61: dist=0.0005s, sort=0.0010s, vote=0.0005s, retention=0.0010s, total=0.0030s
# Instance 62: dist=0.0005s, sort=0.0015s, vote=0.0005s, retention=0.0000s, total=0.0025s
# Instance 63: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 64: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 65: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 66: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 67: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0020s
# Instance 68: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 69: dist=0.0005s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0020s
# Instance 70: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 71: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 72: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 73: dist=0.0010s, sort=0.0015s, vote=0.0000s, retention=0.0010s, total=0.0035s
# Instance 74: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 75: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 76: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 77: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 78: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 79: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 80: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 81: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 82: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 83: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 84: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 85: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 86: dist=0.0005s, sort=0.0005s, vote=0.0004s, retention=0.0000s, total=0.0014s
# Instance 87: dist=0.0006s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0011s
# Instance 88: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 89: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 90: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 91: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 92: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 93: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 94: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 95: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 96: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 97: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 98: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 99: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 100: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 101: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 102: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 103: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 104: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 105: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 106: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 107: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 108: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 109: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 110: dist=0.0000s, sort=0.0000s, vote=0.0011s, retention=0.0000s, total=0.0011s
# Instance 111: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 112: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 113: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 114: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 115: dist=0.0010s, sort=0.0004s, vote=0.0000s, retention=0.0006s, total=0.0020s
# Instance 116: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 117: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 118: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 119: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 120: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 121: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 122: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 123: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 124: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 125: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 126: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 127: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 128: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 129: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 130: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 131: dist=0.0000s, sort=0.0011s, vote=0.0000s, retention=0.0005s, total=0.0016s
# Instance 132: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 133: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 134: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 135: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 136: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 137: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 138: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 139: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 140: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 141: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 142: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 143: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 144: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 145: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 146: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 147: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 148: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 149: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0010s
# Instance 150: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 151: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 152: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 153: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 154: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 155: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 156: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 157: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 158: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 159: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 160: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 161: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 162: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 163: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 164: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 165: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 166: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 167: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 168: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 169: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0010s, total=0.0020s
# Instance 170: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0010s, total=0.0020s
# Instance 171: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 172: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 173: dist=0.0005s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 174: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 175: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 176: dist=0.0010s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0020s
# Instance 177: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 178: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 179: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 180: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 181: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 182: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0000s
# Instance 183: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 184: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 185: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 186: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 187: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 188: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 189: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 190: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 191: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 192: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 193: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 194: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 195: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 196: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 197: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 198: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 199: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 200: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 201: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 202: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 203: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 204: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 205: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 206: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 207: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 208: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 209: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 210: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 211: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 212: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 213: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 214: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 215: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 216: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 217: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 218: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 219: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 220: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 221: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 222: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 223: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 224: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0010s
# Instance 225: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 226: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 227: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0010s
# Instance 228: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 229: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 230: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 231: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 232: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 233: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 234: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 235: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 236: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 237: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 238: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 239: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 240: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 241: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 242: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 243: dist=0.0010s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 244: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 245: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 246: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 247: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 248: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 249: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 250: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 251: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 252: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 253: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 254: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 255: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 256: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 257: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 258: dist=0.0010s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0020s
# Instance 259: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 260: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 261: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 262: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 263: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 264: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 265: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 266: dist=0.0000s, sort=0.0015s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 267: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 268: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 269: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 270: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 271: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 272: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 273: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 274: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 275: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 276: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 277: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 278: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 279: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 280: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 281: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 282: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 283: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 284: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 285: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 286: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 287: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 288: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 289: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 290: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 291: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 292: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 293: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 294: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 295: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 296: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 297: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 298: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 299: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 300: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 301: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 302: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 303: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 304: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 305: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 306: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 307: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 308: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 309: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 310: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 311: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 312: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 313: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 314: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 315: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 316: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 317: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 318: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 319: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 320: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 321: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 322: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 323: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 324: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 325: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 326: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 327: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 328: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 329: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 330: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 331: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 332: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 333: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 334: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 335: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 336: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 337: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 338: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 339: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 340: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 341: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0005s, total=0.0015s
# Instance 342: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 343: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 344: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 345: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 346: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 347: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 348: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 349: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0000s
# Instance 350: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 351: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 352: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 353: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 354: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 355: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 356: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 357: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 358: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 359: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 360: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 361: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 362: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 363: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 364: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 365: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 366: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 367: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 368: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 369: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 370: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 371: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 372: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 373: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 374: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 375: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 376: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 377: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 378: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 379: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 380: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 381: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 382: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 383: dist=0.0010s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0020s
# Instance 384: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 385: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 386: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 387: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 388: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 389: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 390: dist=0.0000s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0010s
# Instance 391: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 392: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 393: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 394: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 395: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 396: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 397: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 398: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 399: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 400: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 401: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 402: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 403: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 404: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 405: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 406: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 407: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 408: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 409: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 410: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 411: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 412: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 413: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 414: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 415: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 416: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 417: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 418: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 419: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 420: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 421: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 422: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 423: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 424: dist=0.0000s, sort=0.0015s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 425: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 426: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 427: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 428: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 429: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 430: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 431: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 432: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 433: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 434: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 435: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 436: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 437: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 438: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 439: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 440: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 441: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 442: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 443: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 444: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 445: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 446: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 447: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 448: dist=0.0010s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 449: dist=0.0005s, sort=0.0000s, vote=0.0010s, retention=0.0005s, total=0.0020s
# Instance 450: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 451: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 452: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 453: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 454: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 455: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 456: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 457: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 458: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 459: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 460: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 461: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 462: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 463: dist=0.0010s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0025s
# Instance 464: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 465: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 466: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 467: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0010s, total=0.0020s
# Instance 468: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 469: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 470: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 471: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 472: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 473: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 474: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 475: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 476: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 477: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 478: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 479: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 480: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 481: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 482: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 483: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 484: dist=0.0005s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 485: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 486: dist=0.0005s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 487: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 488: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 489: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 490: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 491: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 492: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 493: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 494: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 495: dist=0.0005s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0020s
# Instance 496: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 497: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 498: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 499: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 500: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 501: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 502: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 503: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 504: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 505: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 506: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 507: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 508: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 509: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 510: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 511: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 512: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 513: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 514: dist=0.0005s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 515: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 516: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 517: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 518: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 519: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 520: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 521: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 522: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 523: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 524: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 525: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 526: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 527: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 528: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 529: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 530: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 531: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 532: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 533: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 534: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 535: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 536: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 537: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 538: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 539: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# ...
# Instance 956: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 957: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 958: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 959: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 960: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 961: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 962: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 963: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 964: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 965: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 966: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 967: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 968: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 969: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 970: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 971: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 972: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 973: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 974: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 975: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 976: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 977: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 978: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 979: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 980: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 981: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 982: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 983: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 984: dist=0.0000s, sort=0.0015s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 985: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 986: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 987: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 988: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 989: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 990: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 991: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 992: dist=0.0000s, sort=0.0015s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 993: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 994: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 995: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 996: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 997: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 998: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 999: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1000: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1001: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1002: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1003: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1004: dist=0.0005s, sort=0.0000s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1005: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1006: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1007: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1008: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1009: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 1010: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1011: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 1012: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1013: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1014: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1015: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1016: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1017: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1018: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1019: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1020: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 1021: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1022: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1023: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1024: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 1025: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1026: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1027: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1028: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1029: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1030: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1031: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1032: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1033: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1034: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1035: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1036: dist=0.0000s, sort=0.0010s, vote=0.0005s, retention=0.0000s, total=0.0015s
# Instance 1037: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1038: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1039: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1040: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1041: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1042: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1043: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1044: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1045: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1046: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1047: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1048: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 1049: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1050: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1051: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1052: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1053: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1054: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1055: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1056: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1057: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1058: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 1059: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1060: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1061: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1062: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1063: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1064: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1065: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1066: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1067: dist=0.0000s, sort=0.0000s, vote=0.0010s, retention=0.0000s, total=0.0010s
# Instance 1068: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1069: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1070: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1071: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0005s, total=0.0015s
# Instance 1072: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1073: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0010s, total=0.0015s
# Instance 1074: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1075: dist=0.0000s, sort=0.0015s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 1076: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1077: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1078: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1079: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1080: dist=0.0000s, sort=0.0005s, vote=0.0005s, retention=0.0000s, total=0.0010s
# Instance 1081: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1082: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1083: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0015s
# Instance 1084: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1085: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0010s
# Instance 1086: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1087: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1088: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0015s
# Instance 1089: dist=0.0005s, sort=0.0000s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1090: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 1091: dist=0.0000s, sort=0.0010s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1092: dist=0.0000s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0005s
# Instance 1093: dist=0.0010s, sort=0.0005s, vote=0.0000s, retention=0.0005s, total=0.0020s
# Instance 1094: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1095: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1096: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Instance 1097: dist=0.0005s, sort=0.0005s, vote=0.0000s, retention=0.0000s, total=0.0010s
# Total time for all instances: 1.38s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 22
#       1 # df_11 = run_suite(
#       2 #     dataset_name="adult",
#       3 #     metrics=METRICS_EUC_COS,
#    (...)     20
#      21 # TEST 2: Pen-based — Euclidean & Cosine (OHE is harmless here; no cats)
# ---> 22 df_2 = run_suite(
#      23     dataset_name="pen-based",
#      24     metrics=METRICS_EUC_COS,
#      25     encoding_for_metrics={
#      26         "euclidean": EncodingStrategy.ONE_HOT_ENCODE,
#      27         "cosine":    EncodingStrategy.ONE_HOT_ENCODE,
#      28     },
#      29     csv_path="results_penbased_eucl_cos.csv",
#      30 )
#
# Cell In[20], line 63, in run_suite(dataset_name, metrics, encoding_for_metrics, csv_path, run_retentions)
#      61 y_true = np.asarray(yte)
#      62 y_pred = np.asarray(preds)
# ---> 63 acc = accuracy_score(y_true, y_pred)
#      64 prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
#      65     y_true, y_pred, average="macro", zero_division=0
#      66 )
#      67 # If you want per-class too:
#
# File c:\Users\Daniel Hess\Documents\Master\IML\ML_Techniques\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\Daniel Hess\Documents\Master\IML\ML_Techniques\.venv\Lib\site-packages\sklearn\metrics\_classification.py:359, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     357 # Compute accuracy for each possible representation
#     358 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 359 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     360 check_consistent_length(y_true, y_pred, sample_weight)
#     362 if y_type.startswith("multilabel"):
#
# File c:\Users\Daniel Hess\Documents\Master\IML\ML_Techniques\.venv\Lib\site-packages\sklearn\metrics\_classification.py:106, in _check_targets(y_true, y_pred)
#     103     y_type = {"multiclass"}
#     105 if len(y_type) > 1:
# --> 106     raise ValueError(
#     107         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     108             type_true, type_pred
#     109         )
#     110     )
#     112 # We can't have more than one value on y_type => The set is no more needed
#     113 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
