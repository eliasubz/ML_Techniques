# %%
import pandas as pd

df = pd.read_csv('../src/results/adult_rerun_results.csv')


metric_code = {"euclidean": "e", "cosine": "c", "heom": "h"}
vote_code   = {"borda": "b", "modified_plurality": "mp"}
ret_code    = {
    "RetentionPolicy.ALWAYS_RETAIN": "AR",
    "RetentionPolicy.NEVER_RETAIN": "NR",
    "RetentionPolicy.DIFFERENT_CLASS_RETENTION": "DC",
    "RetentionPolicy.DD_RETENTION": "DD",
}

def short_config_id(row):
    m = metric_code.get(str(row["metric"]), str(row["metric"])[:2])
    v = vote_code.get(str(row["vote"]), str(row["vote"])[:2])
    r = ret_code.get(str(row["retention"]), str(row["retention"])[:2])
    return f"{m}-k{int(row['k'])}-{v}-{r}"

df["config_id"] = df.apply(short_config_id, axis=1)
df = df.drop(columns=['dataset'])
cols = ["config_id"] + [c for c in df.columns if c != "config_id"]
df = df[cols]

print(df)

# Save to CSV
df.to_csv("./results/results_adult.csv", index=False)
# Out:
#       config_id  metric  k                vote                      retention  \
# 0     c-k3-b-AR  cosine  3               borda  RetentionPolicy.ALWAYS_RETAIN
# 1     c-k3-b-AR  cosine  3               borda  RetentionPolicy.ALWAYS_RETAIN
# 2     c-k3-b-AR  cosine  3               borda  RetentionPolicy.ALWAYS_RETAIN
# 3     c-k3-b-AR  cosine  3               borda  RetentionPolicy.ALWAYS_RETAIN
# 4     c-k3-b-AR  cosine  3               borda  RetentionPolicy.ALWAYS_RETAIN
# ..          ...     ... ..                 ...                            ...
# 715  h-k7-mp-DD    heom  7  modified_plurality   RetentionPolicy.DD_RETENTION
# 716  h-k7-mp-DD    heom  7  modified_plurality   RetentionPolicy.DD_RETENTION
# 717  h-k7-mp-DD    heom  7  modified_plurality   RetentionPolicy.DD_RETENTION
# 718  h-k7-mp-DD    heom  7  modified_plurality   RetentionPolicy.DD_RETENTION
# 719  h-k7-mp-DD    heom  7  modified_plurality   RetentionPolicy.DD_RETENTION
#
#      fold_id  num_folds  n_train  n_test  fit_time_s  predict_time_s  \
# 0          0         10    43958    4884    0.069219       52.741144
# 1          1         10    43959    4883    0.061517       51.574156
# 2          2         10    43957    4885    0.060184       51.290029
# 3          3         10    43958    4884    0.062719       51.020908
# 4          4         10    43957    4885    0.060899       50.703412
# ..       ...        ...      ...     ...         ...             ...
# 715        5         10    43958    4884    0.006138        7.581290
# 716        6         10    43958    4884    0.006049        7.624419
# 717        7         10    43958    4884    0.006376        7.647066
# 718        8         10    43958    4884    0.005853        7.656342
# 719        9         10    43957    4885    0.006027        7.591876
#
#      total_time_s  accuracy  precision_macro  recall_macro  f1_macro  \
# 0       52.810362  0.759009         0.673595      0.682714  0.677709
# 1       51.635673  0.755273         0.666612      0.671875  0.669088
# 2       51.350214  0.757011         0.669408      0.675125  0.672087
# 3       51.083626  0.761876         0.675079      0.680019  0.677422
# 4       50.764310  0.752917         0.663784      0.669319  0.666374
# ..            ...       ...              ...           ...       ...
# 715      7.587428  0.784808         0.704880      0.619065  0.634989
# 716      7.630468  0.785012         0.704113      0.624766  0.641209
# 717      7.653442  0.790131         0.716071      0.629608  0.647458
# 718      7.662194  0.787674         0.710139      0.627113  0.644264
# 719      7.597903  0.779324         0.691238      0.619533  0.634496
#
#      precision_weighted  recall_weighted  f1_weighted  \
# 0              0.765741         0.759009     0.762091
# 1              0.759275         0.755273     0.757176
# 2              0.761270         0.757011     0.759027
# 3              0.765347         0.761876     0.763531
# 4              0.757247         0.752917     0.754969
# ..                  ...              ...          ...
# 715            0.759774         0.784808     0.756989
# 716            0.760729         0.785012     0.759619
# 717            0.767545         0.790131     0.764462
# 718            0.764206         0.787674     0.762100
# 719            0.753424         0.779324     0.754362
#
#                                  confusion_matrix_json
# 0    {"labels": ["<=50K", ">50K"], "matrix": [[3080...
# 1    {"labels": ["<=50K", ">50K"], "matrix": [[3090...
# 2    {"labels": ["<=50K", ">50K"], "matrix": [[3092...
# 3    {"labels": ["<=50K", ">50K"], "matrix": [[3110...
# 4    {"labels": ["<=50K", ">50K"], "matrix": [[3083...
# ..                                                 ...
# 715  {"labels": ["<=50K", ">50K"], "matrix": [[3481...
# 716  {"labels": ["<=50K", ">50K"], "matrix": [[3463...
# 717  {"labels": ["<=50K", ">50K"], "matrix": [[3483...
# 718  {"labels": ["<=50K", ">50K"], "matrix": [[3474...
# 719  {"labels": ["<=50K", ">50K"], "matrix": [[3441...
#
# [720 rows x 20 columns]
