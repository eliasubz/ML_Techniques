# %%
import pandas as pd

df = pd.read_csv('../src/results/adult_results_old_CSV')


metric_code = {"euclidean": "e", "cosine": "c", "heom": "h"}
vote_code   = {"borda": "b", "modified_plurality": "mp"}
ret_code    = {
    "RetentionPolicy.ALWAYS_RETAIN": "AR",
    "RetentionPolicy.NEVER_RETAIN": "NR",
    "RetentionPolicy.DIFFERENT_CLASS_RETENTION": "DC",
    "RetentionPolicy.DD_RETENTION": "DD",
}

def short_config_id(row):
    m = metric_code.get(str(row["metric"]), str(row["metric"])[:2])
    v = vote_code.get(str(row["vote"]), str(row["vote"])[:2])
    r = ret_code.get(str(row["retention"]), str(row["retention"])[:2])
    return f"{m}-k{int(row['k'])}-{v}-{r}"

df["config_id"] = df.apply(short_config_id, axis=1)
df = df.drop(columns=['dataset'])
cols = ["config_id"] + [c for c in df.columns if c != "config_id"]
df = df[cols]

print(df)

# Save to CSV
df.to_csv("./results/results_adult.csv", index=False)
# Out:
#      config_id     metric  k                vote  \
# 0   e-k3-mp-AR  euclidean  3  modified_plurality
# 1   e-k5-mp-AR  euclidean  5  modified_plurality
# 2   e-k7-mp-AR  euclidean  7  modified_plurality
# 3   c-k3-mp-AR     cosine  3  modified_plurality
# 4   c-k5-mp-AR     cosine  5  modified_plurality
# ..         ...        ... ..                 ...
# 67   c-k5-b-DD     cosine  5               borda
# 68   c-k7-b-DD     cosine  7               borda
# 69   h-k3-b-DD       heom  3               borda
# 70   h-k5-b-DD       heom  5               borda
# 71   h-k7-b-DD       heom  7               borda
#
#                         retention  num_folds  n_train_mean  n_test_mean  \
# 0   RetentionPolicy.ALWAYS_RETAIN         10       43957.8       4884.2
# 1   RetentionPolicy.ALWAYS_RETAIN         10       43957.8       4884.2
# 2   RetentionPolicy.ALWAYS_RETAIN         10       43957.8       4884.2
# 3   RetentionPolicy.ALWAYS_RETAIN         10       43957.8       4884.2
# 4   RetentionPolicy.ALWAYS_RETAIN         10       43957.8       4884.2
# ..                            ...        ...           ...          ...
# 67   RetentionPolicy.DD_RETENTION         10       43957.8       4884.2
# 68   RetentionPolicy.DD_RETENTION         10       43957.8       4884.2
# 69   RetentionPolicy.DD_RETENTION         10       43957.8       4884.2
# 70   RetentionPolicy.DD_RETENTION         10       43957.8       4884.2
# 71   RetentionPolicy.DD_RETENTION         10       43957.8       4884.2
#
#     fit_time_s_mean  fit_time_s_std  ...  recall_macro_std  f1_macro_mean  \
# 0          0.086981        0.025134  ...          0.006156       0.650562
# 1          0.114347        0.017936  ...          0.005025       0.645891
# 2          0.111618        0.002769  ...          0.003526       0.641417
# 3          0.106399        0.015563  ...          0.009093       0.679899
# 4          0.110233        0.003656  ...          0.006208       0.683534
# ..              ...             ...  ...               ...            ...
# 67         0.061396        0.001638  ...          0.007739       0.684479
# 68         0.062214        0.001742  ...          0.007286       0.685926
# 69         0.006678        0.000349  ...          0.007281       0.651065
# 70         0.006764        0.000278  ...          0.005165       0.654185
# 71         0.006954        0.000353  ...          0.005609       0.653512
#
#     f1_macro_std  precision_weighted_mean  precision_weighted_std  \
# 0       0.006733                 0.749369                0.005164
# 1       0.006125                 0.755749                0.005694
# 2       0.004272                 0.762293                0.004055
# 3       0.009125                 0.769530                0.006514
# 4       0.006504                 0.776986                0.004807
# ..           ...                      ...                     ...
# 67      0.007620                 0.772993                0.005426
# 68      0.007323                 0.776672                0.005157
# 69      0.007493                 0.746019                0.005451
# 70      0.005597                 0.753385                0.004232
# 71      0.006608                 0.757462                0.005576
#
#     recall_weighted_mean  recall_weighted_std  f1_weighted_mean  \
# 0               0.765591             0.005033          0.755102
# 1               0.779022             0.004904          0.759106
# 2               0.786250             0.003095          0.760245
# 3               0.781356             0.005820          0.773864
# 4               0.793006             0.004355          0.780585
# ..                   ...                  ...               ...
# 67              0.784673             0.004934          0.777186
# 68              0.791184             0.004551          0.780729
# 69              0.743581             0.006429          0.744748
# 70              0.771037             0.003915          0.759003
# 71              0.778408             0.004973          0.761983
#
#     f1_weighted_std                              confusion_matrix_json
# 0          0.004929  {"labels": ["<=50K", ">50K"], "matrix": [[3270...
# 1          0.004604  {"labels": ["<=50K", ">50K"], "matrix": [[3399...
# 2          0.002951  {"labels": ["<=50K", ">50K"], "matrix": [[3472...
# 3          0.006166  {"labels": ["<=50K", ">50K"], "matrix": [[3282...
# 4          0.004433  {"labels": ["<=50K", ">50K"], "matrix": [[3372...
# ..              ...                                                ...
# 67         0.005129  {"labels": ["<=50K", ">50K"], "matrix": [[3292...
# 68         0.004841  {"labels": ["<=50K", ">50K"], "matrix": [[3345...
# 69         0.005896  {"labels": ["<=50K", ">50K"], "matrix": [[3073...
# 70         0.003949  {"labels": ["<=50K", ">50K"], "matrix": [[3302...
# 71         0.004844  {"labels": ["<=50K", ">50K"], "matrix": [[3367...
#
# [72 rows x 29 columns]
